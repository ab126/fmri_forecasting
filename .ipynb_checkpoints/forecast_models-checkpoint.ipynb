# %% [markdown]
# # Load & Parse Data

# %%
import importlib
import utils.parse_data  

importlib.reload(utils.parse_data)
from utils.parse_data import load_dataset_main

# %%
from utils.parse_data import load_dataset_main

dataset, device = load_dataset_main()
# Out:
# Using dataset path: data\pooled_stratified_share
# Loading dataset with fixed schema settings...
# Scanning and loading dataset (optimized fixed schema mode)...
# Loaded: 2144 runs from 6 subjects
# Subjects: ['subjOenz4SHyaO', 'subjQX6R7rImeb', 'subjoVC0sHUB_P', 'subjqFdsBbuiHF', 'subjtySNgRhV65', 'subjxpYwO4azeZ']
# Successfully loaded runs: 2144
# Loading time: 3.15 seconds
# Device: cuda

# %% [markdown]
# # Train Model

# %%
import importlib
import utils.training

importlib.reload(utils.training)
# Out:
# <module 'utils.training' from 'C:\\Users\\bayer\\PycharmProjects\\fmri_connectivity\\forecasting\\utils\\training.py'>

# %%
from utils.training import run_loso_cv
from models.lstm.lstm_model_library import alstm_model_generator
from models.linear_regression.linear_regression_core import linear_regression_generator
from models.exponential_smoothing.exponential_smoothing_core import exponential_smoothing_generator


n_roi, H = 19, 3
alpha = 1.0

model_gen = lambda : alstm_model_generator(n_roi, H)
model_gen = lambda : linear_regression_generator(alpha)
model_gen = lambda: exponential_smoothing_generator(
    H=H,
    trend="add",
    seasonal=None,
    seasonal_periods=None,
)

results_df, model, X_test, Y_test, \
best_model, best_X_test, best_Y_test = run_loso_cv(
    dataset_raw=dataset,
    model_gen=model_gen,
    M=50,
    H=3,
    stride=1,
    num_epochs=20,
    batch_size=512,
    device=device
)
# Out:
# ============================================================
# LOSO-CV | 6 subjects | M=50, H=3
# ============================================================
# LOSO Folds:   0%|          | 0/6 [00:00<?, ?it/s]
# Fold 1/6 | Test subject: subjOenz4SHyaO
# Train subjects: ['subjQX6R7rImeb', 'subjoVC0sHUB_P', 'subjqFdsBbuiHF', 'subjtySNgRhV65', 'subjxpYwO4azeZ']
# Test subjects : ['subjOenz4SHyaO']
# Train runs: 1744
# Test runs : 400
# Train windows: 273110 | Val windows: 30346 | Test windows: 69600 | ROIs: 19
# Training (max 20 epochs, early stopping patience=5)...
#
# Results:
#   MODEL RMSE  : 0.818691
#   Naive RMSE : 1.025474
#   eta        : 0.1147
#   Beat naive : YES
#
# Horizon-wise RMSE:
#   Step 1 RMSE: 0.745562
#   Step 2 RMSE: 0.841973
#   Step 3 RMSE: 0.863704
#   New best eta model saved: subjOenz4SHyaO (eta=0.1147)
#
# Fold 2/6 | Test subject: subjQX6R7rImeb
# Train subjects: ['subjOenz4SHyaO', 'subjoVC0sHUB_P', 'subjqFdsBbuiHF', 'subjtySNgRhV65', 'subjxpYwO4azeZ']
# Test subjects : ['subjQX6R7rImeb']
# Train runs: 1840
# Test runs : 304
# Train windows: 288144 | Val windows: 32016 | Test windows: 52896 | ROIs: 19
# Training (max 20 epochs, early stopping patience=5)...
#
# Results:
#   MODEL RMSE  : 0.774350
#   Naive RMSE : 0.946010
#   eta        : 0.1410
#   Beat naive : YES
#
# Horizon-wise RMSE:
#   Step 1 RMSE: 0.644292
#   Step 2 RMSE: 0.804948
#   Step 3 RMSE: 0.857788
#   New best eta model saved: subjQX6R7rImeb (eta=0.1410)
#
# Fold 3/6 | Test subject: subjoVC0sHUB_P
# Train subjects: ['subjOenz4SHyaO', 'subjQX6R7rImeb', 'subjqFdsBbuiHF', 'subjtySNgRhV65', 'subjxpYwO4azeZ']
# Test subjects : ['subjoVC0sHUB_P']
# Train runs: 1840
# Test runs : 304
# Train windows: 288144 | Val windows: 32016 | Test windows: 52896 | ROIs: 19
# Training (max 20 epochs, early stopping patience=5)...
#
# Results:
#   MODEL RMSE  : 0.801039
#   Naive RMSE : 0.969542
#   eta        : 0.1319
#   Beat naive : YES
#
# Horizon-wise RMSE:
#   Step 1 RMSE: 0.663609
#   Step 2 RMSE: 0.841142
#   Step 3 RMSE: 0.881528
#
# Fold 4/6 | Test subject: subjqFdsBbuiHF
# Train subjects: ['subjOenz4SHyaO', 'subjQX6R7rImeb', 'subjoVC0sHUB_P', 'subjtySNgRhV65', 'subjxpYwO4azeZ']
# Test subjects : ['subjqFdsBbuiHF']
# Train runs: 1821
# Test runs : 323
# Train windows: 285168 | Val windows: 31686 | Test windows: 56202 | ROIs: 19
# Training (max 20 epochs, early stopping patience=5)...
#
# Results:
#   MODEL RMSE  : 0.871019
#   Naive RMSE : 1.120833
#   eta        : 0.0854
#   Beat naive : YES
#
# Horizon-wise RMSE:
#   Step 1 RMSE: 0.764599
#   Step 2 RMSE: 0.909615
#   Step 3 RMSE: 0.929522
#
# Fold 5/6 | Test subject: subjtySNgRhV65
# Train subjects: ['subjOenz4SHyaO', 'subjQX6R7rImeb', 'subjoVC0sHUB_P', 'subjqFdsBbuiHF', 'subjxpYwO4azeZ']
# Test subjects : ['subjtySNgRhV65']
# Train runs: 1731
# Test runs : 413
# Train windows: 271074 | Val windows: 30120 | Test windows: 71862 | ROIs: 19
# Training (max 20 epochs, early stopping patience=5)...
#
# Results:
#   MODEL RMSE  : 0.848758
#   Naive RMSE : 1.055014
#   eta        : 0.0961
#   Beat naive : YES
#
# Horizon-wise RMSE:
#   Step 1 RMSE: 0.732200
#   Step 2 RMSE: 0.881552
#   Step 3 RMSE: 0.920825
#
# Fold 6/6 | Test subject: subjxpYwO4azeZ
# Train subjects: ['subjOenz4SHyaO', 'subjQX6R7rImeb', 'subjoVC0sHUB_P', 'subjqFdsBbuiHF', 'subjtySNgRhV65']
# Test subjects : ['subjxpYwO4azeZ']
# Train runs: 1744
# Test runs : 400
# Train windows: 273110 | Val windows: 30346 | Test windows: 69600 | ROIs: 19
# Training (max 20 epochs, early stopping patience=5)...
#
# Results:
#   MODEL RMSE  : 0.805925
#   Naive RMSE : 1.023983
#   eta        : 0.1292
#   Beat naive : YES
#
# Horizon-wise RMSE:
#   Step 1 RMSE: 0.705684
#   Step 2 RMSE: 0.833067
#   Step 3 RMSE: 0.869802
#
# ============================================================
# LOSO-CV SUMMARY
# ============================================================
#   test_subject  Model_RMSE  Naive_RMSE    eta  beat_naive
# subjOenz4SHyaO    0.818691    1.025474 0.1147        True
# subjQX6R7rImeb    0.774350    0.946010 0.1410        True
# subjoVC0sHUB_P    0.801039    0.969542 0.1319        True
# subjqFdsBbuiHF    0.871019    1.120833 0.0854        True
# subjtySNgRhV65    0.848758    1.055014 0.0961        True
# subjxpYwO4azeZ    0.805925    1.023983 0.1292        True
#
# Mean Model RMSE  : 0.819964
# Mean Naive RMSE : 1.023476
# Mean eta        : 0.1164
# Folds beat naive: 6 / 6
#
# Results saved to loso_results.csv
#
# Best eta fold : subjQX6R7rImeb (eta=0.1410)

# %%
123

# %%
best_model
# Out:
# Ridge()

# %% [markdown]
# # Best Model

# %%
import importlib
import utils.parse_data

importlib.reload(utils.parse_data)
# Out:
# <module 'utils.parse_data' from 'C:\\Users\\bayer\\PycharmProjects\\fmri_connectivity\\forecasting\\utils\\parse_data.py'>

# %%
from utils.parse_data import parse_dataset

X_train, Y_train, X_test, Y_test, device = parse_dataset(M=50, H=3, normalize=True, stride=1, test_ratio=0.2, 
                                                         test_subjects=None, random_state=42, verbose=True)
# Out:
# Using dataset path: data\pooled_stratified_share
# Loading dataset with fixed schema settings...
# Scanning and loading dataset (optimized fixed schema mode)...
# Loaded: 2144 runs from 6 subjects
# Subjects: ['subjOenz4SHyaO', 'subjQX6R7rImeb', 'subjoVC0sHUB_P', 'subjqFdsBbuiHF', 'subjtySNgRhV65', 'subjxpYwO4azeZ']
# Successfully loaded runs: 2144
# Loading time: 3.56 seconds
# Device: cuda
# Normalizing dataset...
# Building sliding windows...
# Splitting by subject...
# Train subjects: ['subjqFdsBbuiHF', 'subjoVC0sHUB_P', 'subjxpYwO4azeZ', 'subjtySNgRhV65']
# Test subjects : ['subjQX6R7rImeb', 'subjOenz4SHyaO']
# Train runs: 1440
# Test runs : 704
# Final shapes - Train: (250560, 50, 19), (250560, 3, 19) | Test: (122496, 50, 19), (122496, 3, 19)

# %%
X_test.shape
# Out:
# (122496, 50, 19)

# %%
import joblib
import numpy as np
import torch
from models.lstm.lstm_model_library import AdvancedLSTM, FmriPredictorAPI
from pathlib import Path

#device = torch.device('cpu')

# 1. Load the packaged model
# model = joblib.load("saves/best_lstm.joblib")
# model = torch.load('best_fmri_sklearn_api.joblib', map_location=device)
model = best_model

# 2. Prepare your data (Example: 1 window of 50 seconds for 19 ROIs)
# Ensure your real data is Z-score normalized!
#my_data = np.random.randn(1, 50, 19) 

# 3. Predict
# Output: Forecast for the next 5 seconds (H=5) -> Shape: (1, 5, 19)
predictions = model.predict(X_test)

print("Inference completed successfully.")
print(f"Forecast for the next {H} steps: {predictions}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 20
#      12 model = best_model
#      14 # 2. Prepare your data (Example: 1 window of 50 seconds for 19 ROIs)
#      15 # Ensure your real data is Z-score normalized!
#      16 #my_data = np.random.randn(1, 50, 19)
#      17
#      18 # 3. Predict
#      19 # Output: Forecast for the next 5 seconds (H=5) -> Shape: (1, 5, 19)
# ---> 20 predictions = model.predict(X_test)
#      22 print("Inference completed successfully.")
#      23 print(f"Forecast for the next {H} steps: {predictions}")
#
# File ~\PycharmProjects\fmri_connectivity\forecast\Lib\site-packages\sklearn\linear_model\_base.py:311, in LinearModel.predict(self, X)
#     297 def predict(self, X):
#     298     """
#     299     Predict using the linear model.
#     300
#    (...)    309         Returns predicted values.
#     310     """
# --> 311     return self._decision_function(X)
#
# File ~\PycharmProjects\fmri_connectivity\forecast\Lib\site-packages\sklearn\linear_model\_base.py:290, in LinearModel._decision_function(self, X)
#     287 def _decision_function(self, X):
#     288     check_is_fitted(self)
# --> 290     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     291     coef_ = self.coef_
#     292     if coef_.ndim == 1:
#
# File ~\PycharmProjects\fmri_connectivity\forecast\Lib\site-packages\sklearn\utils\validation.py:2902, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2900         out = X, y
#    2901 elif not no_val_X and no_val_y:
# -> 2902     out = check_array(X, input_name="X", **check_params)
#    2903 elif no_val_X and not no_val_y:
#    2904     out = _check_y(y, **check_params)
#
# File ~\PycharmProjects\fmri_connectivity\forecast\Lib\site-packages\sklearn\utils\validation.py:1068, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1063     raise ValueError(
#    1064         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1065         "Convert your data to numeric values explicitly instead."
#    1066     )
#    1067 if not allow_nd and array.ndim >= 3:
# -> 1068     raise ValueError(
#    1069         f"Found array with dim {array.ndim},"
#    1070         f" while dim <= 2 is required{context}."
#    1071     )
#    1073 if ensure_all_finite:
#    1074     _assert_all_finite(
#    1075         array,
#    1076         input_name=input_name,
#    1077         estimator_name=estimator_name,
#    1078         allow_nan=ensure_all_finite == "allow-nan",
#    1079     )
#
# ValueError: Found array with dim 3, while dim <= 2 is required by Ridge.

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.version.cuda)
# Out:
# 2.11.0+cu130
# False
# 0
# 13.0
