# %% [markdown]
# # Load & Parse Data

# %%
import importlib
import utils.parse_data  

importlib.reload(utils.parse_data)
# Out:
# <module 'utils.parse_data' from 'C:\\Users\\bayer\\PycharmProjects\\fmri_connectivity\\forecasting\\utils\\parse_data.py'>

# %%
from utils.parse_data import parse_dataset

X_train, Y_train, X_test, Y_test, device = parse_dataset(M=50, H=3, normalize=True, stride=1, test_ratio=0.2,
                                                         test_subjects=None, random_state=42, verbose=True)
# Out:
# Using dataset path: data\train_pooled_stratified_share
# Loading dataset with fixed schema settings...
# Scanning and loading dataset (optimized fixed schema mode)...
# Loaded: 2144 runs from 6 subjects
# Subjects: ['subjOenz4SHyaO', 'subjQX6R7rImeb', 'subjoVC0sHUB_P', 'subjqFdsBbuiHF', 'subjtySNgRhV65', 'subjxpYwO4azeZ']
# Successfully loaded runs: 2144
# Loading time: 1.84 seconds
# Device: cuda
# Normalizing dataset...
# Building sliding windows...
# Splitting by subject...
# Train subjects: ['subjqFdsBbuiHF', 'subjoVC0sHUB_P', 'subjxpYwO4azeZ', 'subjtySNgRhV65']
# Test subjects : ['subjQX6R7rImeb', 'subjOenz4SHyaO']
# Train runs: 1440
# Test runs : 704
# Final shapes - Train: (250560, 50, 19), (250560, 3, 19) | Test: (122496, 50, 19), (122496, 3, 19)

# %%
from models.transformer.transformer_api_library import transformer_model_generator

model_gen = lambda: transformer_model_generator(
    n_roi=19,
    M=50,
    H=3,
    d_model=64,
    nhead=4,
    num_layers=2,
    dropout=0.1,
)

model = model_gen()

# %%
import importlib
import utils.measures  

importlib.reload(utils.measures)
# Out:
# <module 'utils.measures' from 'C:\\Users\\bayer\\PycharmProjects\\fmri_connectivity\\forecasting\\utils\\measures.py'>

# %%
from utils.measures import compute_di_from_log_prob_api, FlowPredictorAPI
from src.training import train_forecasting_model

flow_transformer_api = FlowPredictorAPI(model)

DI_flow = compute_di_from_log_prob_api(
    model=flow_transformer_api,
    X=X_test,
    Y=Y_test,
    horizon_idx=0,
    reduction_mode="zero",
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 5
#       1 from utils.measures import compute_di_from_log_prob_api, FlowPredictorAPI
#       3 flow_transformer_api = FlowPredictorAPI(model)
# ----> 5 DI_flow = compute_di_from_log_prob_api(
#       6     model=flow_transformer_api,
#       7     X=X_test,
#       8     Y=Y_test,
#       9     horizon_idx=0,
#      10     reduction_mode="zero",
#      11 )
#
# File ~\PycharmProjects\fmri_connectivity\forecasting\utils\measures.py:81, in compute_di_from_log_prob_api(model, X, Y, horizon_idx, reduction_mode, batch_size, rng)
#      78 N, M, R = X.shape
#      79 DI = np.zeros((R, R), dtype=np.float32)
# ---> 81 full_pred = model.predict_proba(X, batch_size=batch_size)
#      83 for source_roi in range(R):
#      84     X_red = make_reduced_input(
#      85         X,
#      86         source_roi=source_roi,
#      87         mode=reduction_mode,
#      88         rng=rng,
#      89     )
#
# File ~\PycharmProjects\fmri_connectivity\forecasting\utils\measures.py:201, in FlowPredictorAPI.predict_proba(self, X, batch_size)
#     197         xb = torch.tensor(X[start:end], dtype=torch.float32).to(self.device)
#     199         # Your model should implement this.
#     200         # Output shape: (batch, H, ROI)
# --> 201         logp_batch = self.model_obj.log_prob_next(xb)
#     203         logps.append(logp_batch.cpu().numpy())
#     205 return {
#     206     "log_prob": np.concatenate(logps, axis=0)
#     207 }
#
# File ~\PycharmProjects\fmri_connectivity\forecast\Lib\site-packages\torch\nn\modules\module.py:1968, in Module.__getattr__(self, name)
#    1966     if name in modules:
#    1967         return modules[name]
# -> 1968 raise AttributeError(
#    1969     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1970 )
#
# AttributeError: 'TransformerForecastModel' object has no attribute 'log_prob_next'

# %%
from utils.measures import compute_di_from_log_prob_api
