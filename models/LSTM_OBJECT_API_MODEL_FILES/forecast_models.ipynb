# %% [markdown]
# # Load & Parse Data

# %%
import joblib
import numpy as np
import torch
from model_library import AdvancedLSTM, FmriPredictorAPI
from pathlib import Path

#device = torch.device('cpu')

# 1. Load the packaged model
model = joblib.load("best_fmri_sklearn_api.joblib")
#model = torch.load('best_fmri_sklearn_api.joblib', map_location=device)

# 2. Prepare your data (Example: 1 window of 50 seconds for 19 ROIs)
# Ensure your real data is Z-score normalized!
my_data = np.random.randn(1, 50, 19) 

# 3. Predict
# Output: Forecast for the next 5 seconds (H=5) -> Shape: (1, 5, 19)
predictions = model.predict(my_data)

print("Inference completed successfully.")
print(f"Forecast for the next 5 steps: {predictions}")
# Out:
# Inference completed successfully.
# Forecast for the next 5 steps: [[[-0.21327917 -0.3099597   0.36702502 -0.22373728 -0.10354503
#    -0.8316425  -0.2154607  -0.24930665 -0.11103532 -0.38199425
#    -0.5126956  -1.0351661  -0.19257526 -1.2935367  -0.08991189
#     0.06284314 -0.01651929  0.24570043 -0.31092098]
#   [-0.01612436 -0.11289838  0.05268324 -0.11197709 -0.0957681
#    -0.35985348 -0.01019349  0.15662469 -0.06486844 -0.0497619
#    -0.3430007  -0.7393875   0.03456397 -1.0927867  -0.07560892
#    -0.07417512  0.0635138  -0.04061533  0.16403565]
#   [ 0.0488602  -0.16236821  0.10388924 -0.05496629 -0.00135419
#    -0.25553736 -0.01979589  0.18252474 -0.09792905  0.02776077
#    -0.225165   -0.63768727  0.20268518 -0.61425894  0.00249408
#    -0.04725041  0.12740651 -0.04833424  0.04873671]]]
# C:\Users\bayer\PycharmProjects\fmri_connectivity\forecast\Lib\site-packages\torch\nn\modules\rnn.py:1169: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\cudnn\RNN.cpp:1479.)
#   result = _VF.lstm(

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.version.cuda)
# Out:
# 2.11.0+cu130
# False
# 0
# 13.0
